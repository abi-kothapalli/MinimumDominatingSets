# %%
import networkx as nx
from sage.graphs.graph_generators_pyx import RandomGNP


# generator can either be erdos_renyi_graph or RandomGNP
def generateGraph(n, density, generator = nx.erdos_renyi_graph):
    g = generator(n, density)
    
    if type(g) is not sage.graphs.graph.Graph:
        g = Graph(g)
        
    return g


def computeMDS(graph):
    dominating_set = graph.dominating_set()
    return dominating_set


def verifyMDS(graph, dominating_set):
    return nx.algorithms.dominating.is_dominating_set(graph.networkx_graph(), dominating_set) and g.is_dominating(dominating_set)

# %%
g = generateGraph(50, 0.2)
mds = g.dominating_set()
print(mds)
print(len(mds))
print(sum(len(x)==len(mds) for x in g.minimal_dominating_sets()))
g.show()
# Out:
# [7, 14, 19, 22, 45, 47, 48]
# 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_67557/1273849606.py in <module>
#       3 print(mds)
#       4 print(len(mds))
# ----> 5 print(sum(len(x)==len(mds) for x in g.minimal_dominating_sets()))
#       6 g.show()
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/misc/functional.py in symbolic_sum(expression, *args, **kwds)
#     574         return expression.sum(*args, **kwds)
#     575     elif len(args) <= 1:
# --> 576         return sum(expression, *args)
#     577     else:
#     578         from sage.symbolic.ring import SR
#
# /tmp/ipykernel_67557/1273849606.py in <genexpr>(.0)
#       3 print(mds)
#       4 print(len(mds))
# ----> 5 print(sum(len(x)==len(mds) for x in g.minimal_dominating_sets()))
#       6 g.show()
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in minimal_dominating_sets(G, to_dominate, work_on_copy)
#     783     peeling = _peel(G, vertices_to_dominate)
#     784
# --> 785     for dom in tree_search(G, peeling, set(), 0):
#     786         yield {int_to_vertex[v] for v in dom}
#     787
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in tree_search(H, plng, dom, i)
#     757                 # If canD is a legitimate child of dom and is not redundant, we
#     758                 # recurse on it:
# --> 759                 for Di in tree_search(H, plng, canD, i + 1):
#     760                     yield Di
#     761     ##
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in tree_search(H, plng, dom, i)
#     757                 # If canD is a legitimate child of dom and is not redundant, we
#     758                 # recurse on it:
# --> 759                 for Di in tree_search(H, plng, canD, i + 1):
#     760                     yield Di
#     761     ##
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in tree_search(H, plng, dom, i)
#     757                 # If canD is a legitimate child of dom and is not redundant, we
#     758                 # recurse on it:
# --> 759                 for Di in tree_search(H, plng, canD, i + 1):
#     760                     yield Di
#     761     ##
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in tree_search(H, plng, dom, i)
#     757                 # If canD is a legitimate child of dom and is not redundant, we
#     758                 # recurse on it:
# --> 759                 for Di in tree_search(H, plng, canD, i + 1):
#     760                     yield Di
#     761     ##
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in tree_search(H, plng, dom, i)
#     757                 # If canD is a legitimate child of dom and is not redundant, we
#     758                 # recurse on it:
# --> 759                 for Di in tree_search(H, plng, canD, i + 1):
#     760                     yield Di
#     761     ##
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in tree_search(H, plng, dom, i)
#     757                 # If canD is a legitimate child of dom and is not redundant, we
#     758                 # recurse on it:
# --> 759                 for Di in tree_search(H, plng, canD, i + 1):
#     760                     yield Di
#     761     ##
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in tree_search(H, plng, dom, i)
#     757                 # If canD is a legitimate child of dom and is not redundant, we
#     758                 # recurse on it:
# --> 759                 for Di in tree_search(H, plng, canD, i + 1):
#     760                     yield Di
#     761     ##
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in tree_search(H, plng, dom, i)
#     757                 # If canD is a legitimate child of dom and is not redundant, we
#     758                 # recurse on it:
# --> 759                 for Di in tree_search(H, plng, canD, i + 1):
#     760                     yield Di
#     761     ##
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in tree_search(H, plng, dom, i)
#     757                 # If canD is a legitimate child of dom and is not redundant, we
#     758                 # recurse on it:
# --> 759                 for Di in tree_search(H, plng, canD, i + 1):
#     760                     yield Di
#     761     ##
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in tree_search(H, plng, dom, i)
#     747               for vert in dom))
#     748
# --> 749         for can_ext in _cand_ext_enum(H, to_dom, u_next):
#     750
#     751             # We complete dom with can_ext -> canD
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in _cand_ext_enum(G, to_dom, u_next)
#     570     # dominating sets while avoiding repeated outputs
#     571     for (X, i) in _aux_with_rep(G, to_dom, u_next):
# --> 572         for (Y, j) in _aux_with_rep(G, to_dom, u_next):
#     573             if j >= i:
#     574                 # This is the first time we meet X: we output it
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in _aux_with_rep(H, to_dom, u_next)
#     555                 # Here again we recurse on a smaller instance at it
#     556                 # excludes u_next (and w)
# --> 557                 for Q in H.minimal_dominating_sets(remains_to_dom):
#     558                     ext = set(Q)
#     559                     ext.add(w)
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in minimal_dominating_sets(G, to_dominate, work_on_copy)
#     783     peeling = _peel(G, vertices_to_dominate)
#     784
# --> 785     for dom in tree_search(G, peeling, set(), 0):
#     786         yield {int_to_vertex[v] for v in dom}
#     787
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in tree_search(H, plng, dom, i)
#     747               for vert in dom))
#     748
# --> 749         for can_ext in _cand_ext_enum(H, to_dom, u_next):
#     750
#     751             # We complete dom with can_ext -> canD
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in _cand_ext_enum(G, to_dom, u_next)
#     570     # dominating sets while avoiding repeated outputs
#     571     for (X, i) in _aux_with_rep(G, to_dom, u_next):
# --> 572         for (Y, j) in _aux_with_rep(G, to_dom, u_next):
#     573             if j >= i:
#     574                 # This is the first time we meet X: we output it
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in _aux_with_rep(H, to_dom, u_next)
#     555                 # Here again we recurse on a smaller instance at it
#     556                 # excludes u_next (and w)
# --> 557                 for Q in H.minimal_dominating_sets(remains_to_dom):
#     558                     ext = set(Q)
#     559                     ext.add(w)
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in minimal_dominating_sets(G, to_dominate, work_on_copy)
#     781         return
#     782
# --> 783     peeling = _peel(G, vertices_to_dominate)
#     784
#     785     for dom in tree_search(G, peeling, set(), 0):
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/domination.py in _peel(G, A)
#     465
#     466     peeling = []
# --> 467     H = copy(G)
#     468     H.delete_vertices(list(Acomp))
#     469     del Acomp
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/copy.py in copy(x)
#      82     copier = getattr(cls, "__copy__", None)
#      83     if copier is not None:
# ---> 84         return copier(x)
#      85
#      86     reductor = dispatch_table.get(cls)
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/generic_graph.py in __copy__(self)
#    1233             5
#    1234         """
# -> 1235         return self.copy(immutable=False)
#    1236
#    1237     def export_to_file(self, filename, format=None, **kwds):
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/generic_graph.py in copy(self, weighted, data_structure, sparse, immutable)
#    1191                 data_structure = "sparse"
#    1192
# -> 1193         G = self.__class__(self, name=self.name(), pos=copy(self._pos),
#    1194                            weighted=weighted,
#    1195                            data_structure=data_structure)
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/graph.py in __init__(self, data, pos, loops, format, weighted, data_structure, vertex_labels, name, multiedges, convert_empty_dict_labels_to_None, sparse, immutable)
#    1169         elif format == 'Graph':
#    1170             if loops is None:
# -> 1171                 loops = data.allows_loops()
#    1172             if multiedges is None:
#    1173                 multiedges = data.allows_multiple_edges()
#
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/graphs/generic_graph.py in allows_loops(self)
#    2666         return self.allows_loops() and any(self.has_edge(v, v) for v in self)
#    2667
# -> 2668     def allows_loops(self):
#    2669         """
#    2670         Return whether loops are permitted in the (di)graph
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
print(computeMDS(g))
# Out:
# [17, 35, 37, 48, 55, 90, 99]
